# %% [markdown]
# ## Asynchronous scraping

# %%
pip install aiohttp
# Out:
# Collecting aiohttp
#   Downloading aiohttp-3.14.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp)
#   Downloading multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp)
#   Downloading propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: typing_extensions>=4.4 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp) (4.15.0)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp)
#   Downloading yarl-1.24.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (103 kB)
# Requirement already satisfied: idna>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.11)
# Downloading aiohttp-3.14.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 52.1 MB/s  0:00:00
# Downloading multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading yarl-1.24.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (109 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Downloading propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (61 kB)
# Installing collected packages: propcache, multidict, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [aiohttp]m6/7 [aiohttp]
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 frozenlist-1.8.0 multidict-6.7.1 propcache-0.5.2 yarl-1.24.5
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install asyncio
# Out:
# Collecting asyncio
#   Downloading asyncio-4.0.0-py3-none-any.whl.metadata (994 bytes)
# Downloading asyncio-4.0.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: asyncio
# Successfully installed asyncio-4.0.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import csv
import re

# %%
# !pip install nest-asycio
import nest_asyncio
nest_asyncio.apply()
# Out:
# ERROR: Could not find a version that satisfies the requirement nest-asycio (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for nest-asycio

# %%
async def scrap_and_save_links(text):
  soup = BeautifulSoup(text, 'html.parser')
  file = open('csv_file', 'a', newline='')
  writer = csv.writer(file, delimiter=',')
  for link in soup.find_all('a', attrs={'href': re.compile("^https:")}):
    link = link.get('href')
    writer.writerow([link])
    file.close()
